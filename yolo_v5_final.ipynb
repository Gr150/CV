# %%
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.8.8 torch-2.0.1+cu117 CUDA:0 (Tesla K80, 12207MiB)
# Setup complete ✅ (32 CPUs, 125.5 GB RAM, 43.0/229.8 GB disk)

# %%
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ...
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ...
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ...

# %%
#Counting the number of dataset
import os

# %%
cd
# Out:
# /share/home2/gurureddyg

# %%
cd yolov5
# Out:
# /share/home2/gurureddyg/yolov5

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="RayG3V59c0EXoitsTKSB")
project = rf.workspace("jacobs-workspace").project("sku-110k")
dataset = project.version(6).download("yolov5")

# %%
ls
# Out:
# benchmarks.py    hubconf.py        runs/                 utils/
# CITATION.cff     LICENSE           segment/              val.py
# classify/        models/           setup.cfg             Yolo_utils.ipynb
# CONTRIBUTING.md  __pycache__/      SKU110K-1000-2000-3/  yolov5s.pt
# data/            README.md         SKU-110k-4/           yolov7/
# detect.py        README.zh-CN.md   train.py              yolov7.ipynb
# export.py        requirements.txt  tutorial.ipynb

# %%
cd yolov5
# Out:
# /share/home2/gurureddyg/yolov5

# %%
ls
# Out:
# benchmarks.py    hubconf.py        runs/                 val.py
# CITATION.cff     LICENSE           segment/              Yolo_utils.ipynb
# classify/        models/           setup.cfg             yolov5s.pt
# CONTRIBUTING.md  __pycache__/      SKU110K-1000-2000-3/  yolov7/
# data/            README.md         train.py              yolov7.ipynb
# detect.py        README.zh-CN.md   tutorial.ipynb
# export.py        requirements.txt  utils/

# %%
import os

def count_jpg_images_in_folder(folder_path):
    jpg_image_count = 0
    images_folder = os.path.join(folder_path, 'images')

    for filename in os.listdir(images_folder):
        if filename.lower().endswith('.jpg'):
            jpg_image_count += 1

    return jpg_image_count

def count_jpg_images_in_folders(main_folder):
    subfolders = ['train', 'test', 'valid']
    folder_counts = {}

    for subfolder in subfolders:
        folder_path = os.path.join(main_folder, subfolder)
        folder_counts[subfolder] = count_jpg_images_in_folder(folder_path)

    return folder_counts

if __name__ == "__main__":
    main_folder = 'yolov5/SKU-110k-4'  # Replace with the path to your main folder
    jpg_image_counts = count_jpg_images_in_folders(main_folder)

    print("Number of JPG images in each folder:")
    for folder, count in jpg_image_counts.items():
        print(f"{folder}: {count} images")

# %%
cd
# Out:
# /share/home2/gurureddyg

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="RayG3V59c0EXoitsTKSB")
project = rf.workspace("jacobs-workspace").project("sku-110k")
dataset = project.version(6).download("yolov5")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to SKU-110k-6 in yolov5pytorch:: 100%|██████████| 10010/10010 [00:19<00:00, 505.76it/s]

# %%
ls
# Out:
# Desktop/          SKU110K-1000-2000-3/  slurm-5054105.out  wandb/
# Jupyter/          SKU-110k-6/           slurm-5054106.out  yolov5/
# jupyterlab.slurm  slurm-5054088.out     slurm-5054107.out  yolov7/
# jupyter.log       slurm-5054091.out     slurm-5054492.out  yolov8n.pt
# myenv/            slurm-5054099.out     VNCJOB
# runs/             slurm-5054102.out     vnc.log

# %%
import os

def count_jpg_images_in_folder(folder_path):
    jpg_image_count = 0
    images_folder = os.path.join(folder_path, 'images')

    for filename in os.listdir(images_folder):
        if filename.lower().endswith('.jpg'):
            jpg_image_count += 1

    return jpg_image_count

def count_jpg_images_in_folders(main_folder):
    subfolders = ['train', 'test', 'valid']
    folder_counts = {}

    for subfolder in subfolders:
        folder_path = os.path.join(main_folder, subfolder)
        folder_counts[subfolder] = count_jpg_images_in_folder(folder_path)

    return folder_counts

if __name__ == "__main__":
    main_folder = './SKU-110k-6'  # Replace with the path to your main folder
    jpg_image_counts = count_jpg_images_in_folders(main_folder)

    print("Number of JPG images in each folder:")
    for folder, count in jpg_image_counts.items():
        print(f"{folder}: {count} images")
# Out:
# Number of JPG images in each folder:
# train: 6998 images
# test: 1000 images
# valid: 2000 images

# %%
# !python train.py --img 416 --batch 32 --epochs 100 --data './SKU-110k-6/data.yaml' --name yolov5s_results --cache
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
# !python train.py --resume
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
# !python train.py --img 416 --batch 32 --epochs 100 --data '/content/yolov5/SKU110K-1000-2000-3/data.yaml' --name yolov5s_results --cache
# Out:
# Traceback (most recent call last):
#   File "train.py", line 35, in <module>
#     import torch
# ModuleNotFoundError: No module named 'torch'

# %%
ls weights/

# %%
ls
# Out:
# benchmarks.py    hubconf.py        runs/                 utils/
# CITATION.cff     LICENSE           segment/              val.py
# classify/        models/           setup.cfg             wandb/
# CONTRIBUTING.md  __pycache__/      SKU110K-1000-2000-3/  Yolo_utils.ipynb
# data/            README.md         SKU-110k-6/           yolov5s.pt
# detect.py        README.zh-CN.md   train.py              yolov7/
# export.py        requirements.txt  tutorial.ipynb        yolov7.ipynb

# %%
ls runs/train/
# Out:
# yolov5s_results/   yolov5s_results3/  yolov5s_results5/  yolov7_results/
# yolov5s_results2/  yolov5s_results4/  yolov5s_results6/  yolov7_results2/

# %%
ls runs/train/yolov5s_results5/
# Out:
# confusion_matrix.png                                    results.png
# events.out.tfevents.1690896309.zeus400.bullx.1769311.0  train_batch0.jpg
# events.out.tfevents.1690896760.zeus400.bullx.1770785.0  train_batch1.jpg
# F1_curve.png                                            train_batch2.jpg
# hyp.yaml                                                val_batch0_labels.jpg
# labels_correlogram.jpg                                  val_batch0_pred.jpg
# labels.jpg                                              val_batch1_labels.jpg
# opt.yaml                                                val_batch1_pred.jpg
# P_curve.png                                             val_batch2_labels.jpg
# PR_curve.png                                            val_batch2_pred.jpg
# R_curve.png                                             weights/
# results.csv

# %%
ls runs/train/yolov5s_results5/weights/last.pt
# Out:
# runs/train/yolov5s_results5/weights/last.pt

# %%
cd yolov5/
# Out:
# [Errno 2] No such file or directory: 'yolov5/'
# /share/home2/gurureddyg/yolov5

# %%
cd /share/home2/gurureddyg/yolov5
# Out:
# /share/home2/gurureddyg/yolov5

# %%
ls
# Out:
# benchmarks.py    hubconf.py        runs/                 utils/
# CITATION.cff     LICENSE           segment/              val.py
# classify/        models/           setup.cfg             wandb/
# CONTRIBUTING.md  __pycache__/      SKU110K-1000-2000-3/  Yolo_utils.ipynb
# data/            README.md         SKU-110k-6/           yolov5s.pt
# detect.py        README.zh-CN.md   train.py              yolov7/
# export.py        requirements.txt  tutorial.ipynb        yolov7.ipynb

# %%
# %run detect.py --weights runs/train/yolov5s_results5/weights/last.pt --img 416 --conf 0.4 --source ./SKU-110k-6/test/images
# Out:
# detect: weights=['runs/train/yolov5s_results5/weights/last.pt'], source=./SKU-110k-6/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.8.8 torch-2.0.1+cu117 CUDA:0 (Tesla K80, 12207MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1000 /share/home2/gurureddyg/yolov5/SKU-110k-6/test/images/test_1004_jpg.rf.0871920603467b8451a4f685a95aabbb.jpg: 416x256 149 objects, 19.0ms
# ...

# %%
#Bounding boxes predicted by  trained YOLOv5 model on test set images

import glob
from IPython.display import Image, display
print("okay1")

for imageName in glob.glob('/share/home2/gurureddyg/yolov5/runs/detect/exp13/*.jpg'): #assuming JPG
    print("entering for loop")
    display(Image(filename=imageName))
    print("\n")
